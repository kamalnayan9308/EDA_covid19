# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.pandas.set_option('display.max_columns',None)

# %%
df= pd.read_csv('Latest Covid-19 India Status.csv')

# %% [markdown]
# This is our country's data as per 8th September.

# %%
df.head()      #first five rows of the data
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  \
# 0  Andaman and Nicobar         7572       6        7437     129
# 1       Andhra Pradesh      2022064   14550     1993589   13925
# 2    Arunachal Pradesh        53408     634       52507     267
# 3                Assam       592616    6415      580491    5710
# 4                Bihar       725759      55      716048    9656
#
#    Active Ratio (%)  Discharge Ratio (%)  Death Ratio (%)
# 0              0.08                98.22             1.70
# 1              0.72                98.59             0.69
# 2              1.19                98.31             0.50
# 3              1.08                97.95             0.96
# 4              0.01                98.66             1.33

# %%
df.head(10)
# Out:
#                                   State/UTs  Total Cases  Active  Discharged  \
# 0                       Andaman and Nicobar         7572       6        7437
# 1                            Andhra Pradesh      2022064   14550     1993589
# 2                         Arunachal Pradesh        53408     634       52507
# 3                                     Assam       592616    6415      580491
# 4                                     Bihar       725759      55      716048
# 5                                Chandigarh        65122      35       64273
# 6                              Chhattisgarh      1004668     354      990757
# 7  Dadra and Nagar Haveli and Daman and Diu        10665       2       10659
# 8                                     Delhi      1437991     367     1412542
# 9                                       Goa       174486     885      170391
#
#    Deaths  Active Ratio (%)  Discharge Ratio (%)  Death Ratio (%)
# ...

# %%
df.shape
# Out:
# (36, 8)

# %%
###This data contains 36 rows constituting name of States and Union Territories, and 8 columns.

# %%
df.info()     ##we do not have any values.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   State/UTs            36 non-null     object
#  1   Total Cases          36 non-null     int64
#  2   Active               36 non-null     int64
#  3   Discharged           36 non-null     int64
#  4   Deaths               36 non-null     int64
#  5   Active Ratio (%)     36 non-null     float64
#  6   Discharge Ratio (%)  36 non-null     float64
#  7   Death Ratio (%)      36 non-null     float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 2.4+ KB

# %%
df.isnull().sum()   ###we do not have any null values
# Out:
# State/UTs              0
# Total Cases            0
# Active                 0
# Discharged             0
# Deaths                 0
# Active Ratio (%)       0
# Discharge Ratio (%)    0
# Death Ratio (%)        0
# dtype: int64

# %%
df.describe()
# Out:
#         Total Cases         Active    Discharged         Deaths  \
# count  3.600000e+01      36.000000  3.600000e+01      36.000000
# mean   9.183012e+05   10912.888889  8.951371e+05   12251.166667
# std    1.349550e+06   40262.354605  1.304503e+06   23636.218030
# min    7.572000e+03       2.000000  7.437000e+03       4.000000
# 25%    7.428200e+04     145.500000  7.135150e+04     811.250000
# 50%    4.702955e+05     701.500000  4.616035e+05    5421.500000
# 75%    1.006543e+06    5709.250000  9.925152e+05   13649.000000
# max    6.489800e+06  239338.000000  6.300755e+06  137811.000000
#
#        Active Ratio (%)  Discharge Ratio (%)  Death Ratio (%)
# count         36.000000            36.000000        36.000000
# mean           1.251111            97.483333         1.265833
# std            3.001101             2.885218         0.564777
# min            0.010000            82.280000         0.040000
# 25%            0.047500            97.620000         0.955000
# ...

# %%
total_cases=df['Total Cases']
State_UTs= df['State/UTs']
sns.set(rc={'figure.figsize':(12,9)})
sns.barplot(y=df['State/UTs'] , x=df['Total Cases'],data= df, color='red', )
###this barplot represents total statewise cases
# Out:
# <AxesSubplot:xlabel='Total Cases', ylabel='State/UTs'>

# %%
###Here we observe that Maharashtra has most number of covid cases in the nation followed by Kerala and Tamilnadu

# %%
sns.barplot(y=df['State/UTs'] , x=df['Active'],data= df, color='red' )
# Out:
# <AxesSubplot:xlabel='Active', ylabel='State/UTs'>

# %%
###Kerala has the most active cases followed by Maharashtra.

# %%
sns.barplot(y=df['State/UTs'] , x=df['Deaths'],data= df, color='red' )
# Out:
# <AxesSubplot:xlabel='Deaths', ylabel='State/UTs'>

# %%
###Maharashtra has most number of deaths followed by Karnataka

# %%
df.corr()
# Out:
#                      Total Cases    Active  Discharged    Deaths  \
# Total Cases             1.000000  0.598934    0.999808  0.896170
# Active                  0.598934  1.000000    0.583757  0.275658
# Discharged              0.999808  0.583757    1.000000  0.900489
# Deaths                  0.896170  0.275658    0.900489  1.000000
# Active Ratio (%)       -0.014557  0.278111   -0.022085 -0.086029
# Discharge Ratio (%)    -0.001213 -0.250006    0.005869  0.032672
# Death Ratio (%)         0.084627 -0.200801    0.088472  0.291124
#
#                      Active Ratio (%)  Discharge Ratio (%)  Death Ratio (%)
# Total Cases                 -0.014557            -0.001213         0.084627
# Active                       0.278111            -0.250006        -0.200801
# Discharged                  -0.022085             0.005869         0.088472
# Deaths                      -0.086029             0.032672         0.291124
# ...

# %%
sns.heatmap(df.corr(), annot= True)
# Out:
# <AxesSubplot:>

# %%
df.style.background_gradient(cmap="Reds")
# Out:
# <style  type="text/css" >
# ...

# %%
sns.stripplot(data=df,x='Active Ratio (%)',y='State/UTs', dodge= True, size=10, linewidth=0.1)
# Out:
# <AxesSubplot:xlabel='Active Ratio (%)', ylabel='State/UTs'>

# %%
##Mizoram's active case% is more than other States.

# %%
sns.lineplot(x="Deaths", y="Total Cases",
             data=df)
# Out:
# <AxesSubplot:xlabel='Deaths', ylabel='Total Cases'>
